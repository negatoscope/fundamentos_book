# %% [markdown]
# (evaluation)=
#
# # 5 Ejercicios de evaluación

# %%
import nbinteract as nbi

nbi.multiple_choice(question="What is 10 + 2 * 5?",
                    choices=['12', '60', '20'],
                    answers=2)
